# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('/content/apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (9339, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(5)
# Out:
#                                           App            Category  Rating  \
# 765                                Revista BS  NEWS_AND_MAGAZINES     NaN
# 8476                     Picture Grid Builder         PHOTOGRAPHY    4.00
# 2611                   Evolution Marketing CR  HEALTH_AND_FITNESS     NaN
# 5333           Superbrothers Sword & Sworcery                GAME    4.40
# 6149  SK Enca Direct Malls - Used Cars Search   AUTO_AND_VEHICLES    3.60
#
#        Reviews  Size_MBs   Installs  Type  Price Content_Rating  \
# 765      10.00     19.00        100  Free      0       Everyone
# 8476 33,439.00      3.90  5,000,000  Free      0       Everyone
# 2611     14.00      1.30      1,000  Free      0       Everyone
# 5333 11,023.00     16.00    100,000  Paid  $3.99           Teen
# 6149  1,379.00     16.00    500,000  Free      0       Everyone
#
#                 Genres      Last_Updated   Android_Ver
# 765   News & Magazines  January 13, 2017    4.1 and up
# ...

# %%
genres = df_apps['Genres'].value_counts()
genres.index
# Out:
# Index(['Tools', 'Entertainment', 'Education', 'Medical', 'Business',
#        'Lifestyle', 'Finance', 'Sports', 'Personalization', 'Health & Fitness',
#        ...
#        'Adventure;Brain Games', 'Books & Reference;Creativity',
#        'Lifestyle;Education', 'Card;Brain Games',
#        'Music & Audio;Music & Video', 'Puzzle;Education',
#        'Communication;Creativity', 'Health & Fitness;Education',
#        'Travel & Local;Action & Adventure', 'Strategy;Education'],
#       dtype='object', name='Genres', length=115)

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres'],
#       dtype='object')

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.isna().sum()
# Out:
# App                  0
# Category             1
# Rating            1475
# Reviews              1
# Size_MBs             1
# Installs             1
# Type                 2
# Price                1
# Content_Rating       1
# Genres               1
# dtype: int64

# %%
df_apps_clean = df_apps.dropna()

# %%
print(df_apps_clean.shape)
df_apps_clean['Installs'].value_counts()
df_apps_clean.isna().sum()
# Out:
# (7864, 10)
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size_MBs          0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# dtype: int64

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().value_counts()
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
print(duplicated_rows.shape)
duplicated_rows.head()
# Out:
# (356, 10)
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL    5.00     2.00
# 1133                                 MouseMingle   DATING    2.70     3.00
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40     8.00
# 1231                                Sway Medical  MEDICAL    5.00     3.00
# 1247              Chat Kids - Chat Room For Kids   DATING    4.70     6.00
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946      11.00      100  Free       0     Mature 17+  Medical
# 1133      3.90      100  Free       0     Mature 17+   Dating
# 1196      6.50      100  Paid  $12.99       Everyone  Medical
# 1231     22.00      100  Free       0       Everyone  Medical
# 1247      4.90      100  Free       0     Mature 17+   Dating

# %%
df_apps_clean[df_apps_clean['App'] == 'Instagram']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size_MBs, Installs, Type, Price, Content_Rating, Genres]
# Index: []

# %%
dedup_df = df_apps_clean.drop_duplicates()
dedup_df[dedup_df['App'] == 'Instagram']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size_MBs, Installs, Type, Price, Content_Rating, Genres]
# Index: []

# %%
dedup_df = df_apps_clean.drop_duplicates()
dedup_df[dedup_df['App'] == 'Instagram']
dedup_df.shape
# Out:
# (7508, 10)

# %%
df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'], inplace=True)
# Out:
# <ipython-input-17-37fcf962bced>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'], inplace=True)

# %%
df_apps_clean.shape
# Out:
# (7223, 10)

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sample()
# Out:
#                      App Category  Rating  Reviews  Size_MBs Installs  Type  \
# 4564  Battleheart Legacy   FAMILY    4.60 7,420.00      7.40   50,000  Paid
#
#       Price Content_Rating        Genres
# 4564  $4.99           Teen  Role Playing

# %%
df_apps_clean[df_apps_clean['Rating'] == df_apps_clean['Rating'].max()]
# Out:
#                                                    App   Category  Rating  \
# 21                                 KBA-EZ Health Guide    MEDICAL    5.00
# 28                                            Ra Ga Ba       GAME    5.00
# 47                                             Mu.F.O.       GAME    5.00
# 82                                    Brick Breaker BR       GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App    MEDICAL    5.00
# ...                                                ...        ...     ...
# 2680                               Florida Wildflowers     FAMILY    5.00
# 2750  Superheroes, Marvel, DC, Comics, TV, Movies News     COMICS    5.00
# 3030           CL Keyboard - Myanmar Keyboard (No Ads)      TOOLS    5.00
# 3115                                        Oración CX  LIFESTYLE    5.00
# 4058                          Ek Bander Ne Kholi Dukan     FAMILY    5.00
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating         Genres
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
len(df_apps_clean[df_apps_clean['Size_MBs'] == df_apps_clean['Size_MBs'].max()].index)
# Out:
# 8

# %%
df_apps_clean[df_apps_clean['Size_MBs'] == df_apps_clean['Size_MBs'].max()]
# Out:
#                                                    App            Category  \
# 1795                              Navi Radiography Pro             MEDICAL
# 3144                                        Vi Trainer  HEALTH_AND_FITNESS
# 4176  Car Crash III Beam DH Real Damage Simulator 2018                GAME
# 7926                                         Post Bank             FINANCE
# 7927                       The Walking Dead: Our World                GAME
# 7928                     Stickman Legends: Shadow Wars                GAME
# 8718                 Mini Golf King - Multiplayer Game                GAME
# 8719                        Draft Simulator for FUT 18              SPORTS
#
#       Rating    Reviews  Size_MBs   Installs  Type   Price Content_Rating  \
# 1795    4.70      11.00    100.00        500  Paid  $15.99       Everyone
# 3144    3.60     124.00    100.00      5,000  Free       0       Everyone
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values(by='Reviews', ascending=False)['Type'].value_counts()
# Out:
# Type
# Free    6619
# Paid     604
# Name: count, dtype: int64

# %%
df_apps_clean.sort_values(by='Reviews', ascending=False).head(50)
# Out:
#                                                     App             Category  \
# 9185                                         Homescapes                 GAME
# 8798                                    Fallout Shelter                 GAME
# 9220                                          Minecraft               FAMILY
# 9177                                            Fishdom                 GAME
# 9221                        The Tribez: Build a Village               FAMILY
# 8777                          FRONTLINE COMMANDO: D-DAY                 GAME
# 9318                                    Real Basketball               SPORTS
# 9252                                               Path               SOCIAL
# 9188                     Best Fiends - Free Puzzle Game                 GAME
# 9235                                Madden NFL Football               FAMILY
# 9228    9GAG: Funny Gifs, Pics, Memes & Videos for IGTV               FAMILY
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
import plotly.express as px
ratings = df_apps_clean['Content_Rating'].value_counts() #.count()

# %%
# px.pie( labels=ratings.index, values=ratings.values, names=ratings.index, hole=0.5)
px.pie( labels=ratings.index, values=ratings.values, names=ratings.index, hole=0.5, title='Content Rating')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, names=ratings.index, hole=0.1,title='Content Rating')
fig.update_traces(textposition='outside', textinfo='label+percent')
# fig.update_traces(textfont_size=14)
fig.update_traces(textfont=dict(family="Courier New", size=14, color="blue"))
# fig.update_traces(textposition='outside', textinfo='percent+label')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
)
fig.update_traces(textposition='outside', textinfo='percent+label')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean['Installs'].value_counts()
# Out:
# Installs
# 1,000,000     1417
# 100,000       1096
# 10,000         988
# 1,000          698
# 5,000,000      607
# 500,000        504
# 50,000         457
# 5,000          425
# 10,000,000     392
# 100            303
# 500            199
# 10              69
# 50              56
# 5                9
# 1                3
# Name: count, dtype: int64

# %%
# type(df_apps_clean['Installs'].loc[10835])
# df_apps_clean['Installs']

# %%
df_apps_clean['Installs'].describe()
df_apps_clean['Installs'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7223 entries, 21 to 9337
# Series name: Installs
# Non-Null Count  Dtype
# --------------  -----
# 7223 non-null   object
# dtypes: object(1)
# memory usage: 370.9+ KB

# %%
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 1,000        698
# 1,000,000   1417
# 10            69
# 10,000       988
# 10,000,000   392
# 100          303
# 100,000     1096
# 5              9
# 5,000        425
# 5,000,000    607
# 50            56
# 50,000       457
# 500          199
# 500,000      504

# %%
df_apps_clean.Installs.unique()
df_apps_clean.Installs = df_apps_clean.Installs.str.replace(',', '')
# Out:
# <ipython-input-34-17d8166aaab8>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#            App
# Installs
# 1            3
# 10          69
# 100        303
# 1000       698
# 10000      988
# 100000    1096
# 1000000   1417
# 10000000   392
# 5            9
# 50          56
# 500        199
# 5000       425
# 50000      457
# 500000     504
# 5000000    607

# %%
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
# Out:
# <ipython-input-36-835182d35b98>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# type(df_apps_clean['Installs'].loc[10835])

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price.unique()
df_apps_clean.Price = df_apps_clean.Price.str.replace('$', '')
# Out:
# <ipython-input-37-94097fcd5c48>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_apps_clean.Price.unique()
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)
# Out:
# <ipython-input-38-964d36162bc9>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_apps_clean.Price.unique()
df_apps_clean.sort_values(by='Price', ascending=False).head(20)
df_apps_clean.drop(df_apps_clean[df_apps_clean.Price > 250].index, inplace=True)
# Out:
# <ipython-input-39-dcf1c16e6b54>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean.sort_values(by='Price', ascending=False).head(20)
# Out:
#                                                     App     Category  Rating  \
# 2281                          Vargo Anesthesia Mega App      MEDICAL    4.60
# 1407                                       LTC AS Legal      MEDICAL    4.00
# 2629                                   I am Rich Person    LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture      MEDICAL    3.50
# 2463                                 PTA Content Master      MEDICAL    4.20
# 4264                            Golfshot Plus: Golf GPS       SPORTS    4.10
# 504                           AP Art History Flashcards       FAMILY    5.00
# 2207                                           EMT PASS      MEDICAL    3.40
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...      MEDICAL    4.20
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body      MEDICAL    4.50
# 2293                               Hospitalist Handbook      MEDICAL    4.80
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean.Installs * df_apps_clean.Price
# Out:
# <ipython-input-41-025547c22804>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_apps_clean.sort_values(by='Revenue_Estimate', ascending=False).head(10)[df_apps_clean['Category'] == 'GAME']
# Out:
# <ipython-input-42-fc16d7811cb1>:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#                                 App Category  Rating    Reviews  Size_MBs  \
# 8825                  Hitman Sniper     GAME    4.60 408,292.00     29.00
# 7151  Grand Theft Auto: San Andreas     GAME    4.40 348,962.00     26.00
# 6594            DraStic DS Emulator     GAME    4.60  87,766.00     12.00
#
#       Installs  Type  Price Content_Rating  Genres  Revenue_Estimate
# 8825  10000000  Paid   0.99     Mature 17+  Action      9,900,000.00
# 7151   1000000  Paid   6.99     Mature 17+  Action      6,990,000.00
# 6594   1000000  Paid   4.99       Everyone  Action      4,990,000.00

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean.Category.nunique()
# df_apps_clean.Category.groupby('Category').count()
top10_category = df_apps_clean.Category.value_counts()[:10]

# %%
px.bar(x=top10_category.index, y=top10_category.values)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=False, inplace=True)
category_installs.head()
# Out:
#                  Installs
# Category
# GAME           1318762717
# FAMILY         1237554490
# PHOTOGRAPHY     519143130
# TOOLS           469724500
# COMMUNICATION   449241530

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')

h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
cat_number = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})
cat_number.head()
print(cat_number.shape)
print(category_installs.shape)
# Out:
# (33, 1)
# (33, 1)

# %%
cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how="inner")
print(f'The dimensions of the DataFrame are: {cat_merged_df.shape}')
cat_merged_df.sort_values('Installs', ascending=False)
# Out:
# The dimensions of the DataFrame are: (33, 2)
#                       App    Installs
# Category
# GAME                  676  1318762717
# FAMILY               1475  1237554490
# PHOTOGRAPHY           199   519143130
# TOOLS                 599   469724500
# COMMUNICATION         209   449241530
# HEALTH_AND_FITNESS    233   414006220
# SPORTS                235   386431465
# SHOPPING              146   330331540
# SOCIAL                173   317841475
# TRAVEL_AND_LOCAL      170   314859300
# ENTERTAINMENT          84   293660000
# LIFESTYLE             287   273611120
# PERSONALIZATION       261   242352930
# PRODUCTIVITY          238   238070180
# FINANCE               287   235249400
# BUSINESS              252   212018120
# BOOKS_AND_REFERENCE   158   205791655
# EDUCATION             112   202852000
# NEWS_AND_MAGAZINES    188   199110650
# FOOD_AND_DRINK         86   131677750
# DATING                133   130912410
# MAPS_AND_NAVIGATION   105   113267560
# ...

# %%
scatter = px.scatter(cat_merged_df, # data
                    x='App', # column name
                    y='Installs',
                    title='Category Concentration',
                    size='App',
                    hover_name=cat_merged_df.index,
                    color='Installs')

# %%
scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))

scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cat_merged_df['ratio'] = (cat_merged_df['Installs'] / cat_merged_df['App'] ) / 1000000

# %%
cat_merged_df.sort_values(by=['ratio'], ascending=False).head(10)
# Out:
#                     App    Installs  ratio
# Category
# ENTERTAINMENT        84   293660000   3.50
# PHOTOGRAPHY         199   519143130   2.61
# SHOPPING            146   330331540   2.26
# COMMUNICATION       209   449241530   2.15
# GAME                676  1318762717   1.95
# TRAVEL_AND_LOCAL    170   314859300   1.85
# SOCIAL              173   317841475   1.84
# EDUCATION           112   202852000   1.81
# HEALTH_AND_FITNESS  233   414006220   1.78
# SPORTS              235   386431465   1.64

# %%
fig = px.scatter(cat_merged_df, # data
                    x=cat_merged_df.index, # column name
                    y='ratio',
                    title='Category Concentration',
                    size='ratio',
                    hover_name=cat_merged_df.index,
                    color='ratio')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean.Genres.value_counts()
df_apps_clean.Genres.str.split(';')
# Out:
# 21             [Medical]
# 28              [Arcade]
# 47              [Arcade]
# 82              [Arcade]
# 99             [Medical]
#               ...
# 9333    [Travel & Local]
# 9334    [Travel & Local]
# 9335             [Tools]
# 9336             [Tools]
# 9337             [Tools]
# Name: Genres, Length: 7208, dtype: object

# %%
df_apps_clean.Genres.value_counts()
df_apps_clean.Genres.nunique()
# Out:
# 110

# %%
len(df_apps_clean.Genres.unique())
# Out:
# 110

# %%
stack = df_apps_clean.Genres.str.split(';', expand=True).stack()

# %%
num_genres = stack.value_counts()
# Out:
# Tools                      599
# Education                  575
# Entertainment              459
# Medical                    292
# Lifestyle                  288
# Finance                    287
# Personalization            261
# Business                   252
# Sports                     241
# Productivity               238
# Health & Fitness           235
# Action                     223
# Communication              210
# Photography                199
# News & Magazines           188
# Simulation                 177
# Social                     173
# Casual                     171
# Travel & Local             170
# Books & Reference          160
# Shopping                   146
# Dating                     133
# Arcade                     125
# Video Players & Editors    110
# Maps & Navigation          105
# Puzzle                     103
# Role Playing                92
# Educational                 87
# Food & Drink                86
# Strategy                    76
# ...

# %%
num_genres.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-bd13f7dce5e6> in <cell line: 0>()
#       1 num_genres.shape
# ----> 2 num_genres.count.value_counts()
#
# AttributeError: 'function' object has no attribute 'value_counts'

# %%
# fig = px.bar(x=num_genres.index[:15], y=num_genres.values[:15], color="medal", title="Long-Form Input")
fig = px.bar(num_genres[:15], x=num_genres.index[:15], y=num_genres.values[:15], color="count")
fig.update_layout(xaxis_title='Genres', yaxis_title='Number of Apps')
fig.show()

# fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
bar = px.bar(x = num_genres.index[:15], # index = category name
             y = num_genres.values[:15], # count
             title='Top Genres',
             hover_name=num_genres.index[:15],
             color=num_genres.values[:15],
             color_continuous_scale='Agsunset')

bar.update_layout(xaxis_title='Genre',
yaxis_title='Number of Apps',
coloraxis_showscale=False)

bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
print(df_apps_clean.Type.value_counts())
print(df_apps_clean.head())
# Out:
# Type
# Free    6619
# Paid     589
# Name: count, dtype: int64
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00     4.00
# 28                                         Ra Ga Ba     GAME    5.00     2.00
# 47                                          Mu.F.O.     GAME    5.00     2.00
# 82                                 Brick Breaker BR     GAME    5.00     7.00
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00     1.00
#
#     Size_MBs  Installs  Type  Price Content_Rating   Genres  Revenue_Estimate
# 21     25.00         1  Free   0.00       Everyone  Medical              0.00
# 28     20.00         1  Paid   1.49       Everyone   Arcade              1.49
# 47     16.00         1  Paid   0.99       Everyone   Arcade              0.99
# 82     19.00         5  Free   0.00       Everyone   Arcade              0.00
# ...

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   57
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   70
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %%
g_bar = px.bar(df_free_vs_paid,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')

g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))

g_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box = px.box(df_apps_clean,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')

box.update_layout(yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = px.box(df_paid_apps,
             x='Category',
             y='Revenue_Estimate',
             title='How Much Can Paid Apps Earn?')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))


box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
df_paid_apps.Price.median()
# Out:
# 2.99

# %%
box = px.box(df_paid_apps,
             x='Category',
             y="Price",
             title='Price per Category')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
