# %%
import pandas as pd
df = pd.read_csv('/content/salaries_by_college_major.csv')
df.head(5)
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %% [markdown]
# # **Preliminary Data Exploration and Data Cleaning with Pandas**
#
# Now that we've got our data loaded into our dataframe, we need to take a closer look at it to help us understand what it is we are working with. This is always the first step with any data science project.

# %%
# prompt: How many rows does our dataframe have?
# How many columns does it have?
# What are the labels for the columns? Do the columns have names?
# Are there any missing values in our dataframe? Does our dataframe contain any bad data?

import pandas as pd
df = pd.read_csv('/content/salaries_by_college_major.csv')
# How many rows and columns?
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")

# Column labels and names
print("\nColumn Labels:")
print(df.columns)

# Check for missing values and bad data
print("\nMissing values per column:")
print(df.isnull().sum())

print("\nData types of each column:")
print(df.dtypes)

# Further exploration of potential bad data (e.g., unreasonable values)
# Example: Check for negative starting median salaries
if (df['Starting Median Salary'] < 0).any():
  print("\nWarning: Found negative starting median salaries.")
# You might want to add other checks based on your knowledge of the data.
# Out:
# Number of rows: 51
# Number of columns: 6
#
# Column Labels:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')
#
# Missing values per column:
# Undergraduate Major                  0
# Starting Median Salary               1
# Mid-Career Median Salary             1
# Mid-Career 10th Percentile Salary    1
# Mid-Career 90th Percentile Salary    1
# Group                                1
# dtype: int64
#
# Data types of each column:
# Undergraduate Major                   object
# Starting Median Salary               float64
# Mid-Career Median Salary             float64
# Mid-Career 10th Percentile Salary    float64
# Mid-Career 90th Percentile Salary    float64
# Group                                 object
# dtype: object

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Undergraduate Major                   object
# Starting Median Salary               float64
# Mid-Career Median Salary             float64
# Mid-Career 10th Percentile Salary    float64
# Mid-Career 90th Percentile Salary    float64
# Group                                 object
# dtype: object

# %%
# Missing Values and Junk Data
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
df.isna().sum()
# Out:
# Undergraduate Major                  0
# Starting Median Salary               1
# Mid-Career Median Salary             1
# Mid-Career 10th Percentile Salary    1
# Mid-Career 90th Percentile Salary    1
# Group                                1
# dtype: int64

# %%
clean_df = df.dropna()

# %%
df.isnull()

# %%
df.info
# df.index
# Out:
# <bound method DataFrame.info of                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df.memory_usage()
# Out:
# Index                                132
# Undergraduate Major                  408
# Starting Median Salary               408
# Mid-Career Median Salary             408
# Mid-Career 10th Percentile Salary    408
# Mid-Career 90th Percentile Salary    408
# Group                                408
# dtype: int64

# %%
clean_df.tail()
# df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_df['Starting Median Salary']

# %%
clean_df['Starting Median Salary'].max()
# Out:
# 74300.0

# %%
clean_df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
clean_df.loc[43]
clean_df['Undergraduate Major'][43]
# Out:
# 'Physician Assistant'

# %%
# index vs labels

# import pandas as pd

# data = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}
# df = pd.DataFrame(data, index=['a', 'b'])  # 'a' and 'b' are labels
# print(df.loc['a'])

# data = {
#     'name': ['Dee', 'Sheral', 'Alaynna'],
#     'character': ['learning', 'angel-baby', 'baby-girl']
# }
# df = pd.DataFrame(data=data)
# print(df)

# df['character'][1]

# %%
clean_df['Mid-Career Median Salary'].max()
clean_df['Mid-Career Median Salary'].idxmax()
clean_df['Undergraduate Major']
clean_df.loc[8]
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                            63200.0
# Mid-Career Median Salary                         107000.0
# Mid-Career 10th Percentile Salary                 71900.0
# Mid-Career 90th Percentile Salary                194000.0
# Group                                                STEM
# Name: 8, dtype: object

# %%
clean_df['Mid-Career Median Salary'].min()
clean_df['Mid-Career Median Salary'].idxmin()
clean_df.loc[18]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %%
clean_df['Starting Median Salary'].min()
clean_df['Starting Median Salary'].idxmin()
clean_df.loc[49]
# Out:
# Undergraduate Major                  Spanish
# Starting Median Salary               34000.0
# Mid-Career Median Salary             53100.0
# Mid-Career 10th Percentile Salary    31000.0
# Mid-Career 90th Percentile Salary    96400.0
# Group                                   HASS
# Name: 49, dtype: object

# %%
print(clean_df['Starting Median Salary'].min())
clean_df['Undergraduate Major'].loc[clean_df['Starting Median Salary'].idxmin()]
# Out:
# 34000.0
# 'Spanish'

# %%
clean_df.insert(1,'Difference', clean_df['Mid-Career 90th Percentile Salary'].subtract(clean_df['Mid-Career 10th Percentile Salary']))

# %%
clean_df.head()
# Out:
#      Undergraduate Major  Difference  Starting Median Salary  \
# 0             Accounting    109800.0                 46000.0
# 1  Aerospace Engineering     96700.0                 57700.0
# 2            Agriculture    113700.0                 42600.0
# 3           Anthropology    104200.0                 36800.0
# 4           Architecture     85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %%
low_risk = clean_df.sort_values(by=['Difference'])
low_risk[['Undergraduate Major', 'Difference']]
# Out:
#                      Undergraduate Major  Difference
# 40                               Nursing     50700.0
# 43                   Physician Assistant     57600.0
# 41                             Nutrition     65300.0
# 49                               Spanish     65400.0
# 27            Health Care Administration     66400.0
# 47                              Religion     66700.0
# 23                              Forestry     70000.0
# 32                       Interior Design     71300.0
# 18                             Education     72700.0
# 15                      Criminal Justice     74800.0
# 26                        Graphic Design     76000.0
# 31           Information Technology (IT)     84500.0
# 10                     Civil Engineering     84600.0
# 4                           Architecture     85400.0
# 48                             Sociology     87300.0
# 29                 Hospitality & Tourism     88500.0
# 24                             Geography     92000.0
# ...

# %%
clean_df.sort_values(by=['Mid-Career Median Salary'], ascending=False)
# Out:
#                      Undergraduate Major  Difference  Starting Median Salary  \
# 8                   Chemical Engineering    122100.0                 63200.0
# 12                  Computer Engineering     95900.0                 61400.0
# 19                Electrical Engineering     98700.0                 60900.0
# 1                  Aerospace Engineering     96700.0                 57700.0
# 17                             Economics    159400.0                 50100.0
# 44                               Physics    122000.0                 50300.0
# 13                      Computer Science     98000.0                 55900.0
# 30                Industrial Engineering    115900.0                 57700.0
# 38                Mechanical Engineering     99300.0                 57900.0
# 37                                  Math    137800.0                 45400.0
# 43                   Physician Assistant     57600.0                 74300.0
# ...

# %%
highest_potential = clean_df.sort_values(by=['Mid-Career 90th Percentile Salary'], ascending=False)
highest_potential[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %%
highest_spread = clean_df.sort_values('Difference', ascending=False)
highest_spread[['Undergraduate Major', 'Difference']].head(10)
# Out:
#         Undergraduate Major  Difference
# 17                Economics    159400.0
# 22                  Finance    147800.0
# 37                     Math    137800.0
# 36                Marketing    132900.0
# 42               Philosophy    132500.0
# 45        Political Science    126800.0
# 8      Chemical Engineering    122100.0
# 44                  Physics    122000.0
# 33  International Relations    118800.0
# 16                    Drama    116300.0

# %%
highest_median_difference = clean_df.sort_values(by=['Mid-Career Median Salary'], ascending=False)
highest_median_difference[['Undergraduate Major', 'Difference', 'Mid-Career Median Salary', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#        Undergraduate Major  Difference  Mid-Career Median Salary  \
# 8     Chemical Engineering    122100.0                  107000.0
# 12    Computer Engineering     95900.0                  105000.0
# 19  Electrical Engineering     98700.0                  103000.0
# 1    Aerospace Engineering     96700.0                  101000.0
# 17               Economics    159400.0                   98600.0
#
#     Mid-Career 90th Percentile Salary
# 8                            194000.0
# 12                           162000.0
# 19                           168000.0
# 1                            161000.0
# 17                           210000.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Difference'].plot(kind='hist', bins=20, title='Difference')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_3.groupby('Undergraduate Major').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
clean_df['Group'].unique()
# Out:
# array(['Business', 'STEM', 'HASS'], dtype=object)

# %%
clean_df.groupby(by=['Group'])['Group'].count()
# Out:
# Group
# Business    12
# HASS        22
# STEM        16
# Name: Group, dtype: int64

# %%
# # clean_df.groupby('Group').mean()
# # Select only numeric columns before calculating the mean
# numeric_clean_df = clean_df.select_dtypes(include=['number'])

# # Now calculate the mean for each group
# group_means = numeric_clean_df.groupby('Group').mean()

# # Display the results
# print(group_means)

# %%
clean_df.groupby('Group')['Mid-Career Median Salary'].mean()
# changing PD display settings
pd.options.display.float_format = '{:,.2f}'.format
clean_df.groupby('Group').mean(numeric_only=True).sort_values(by=['Mid-Career Median Salary'], ascending=False)
# .insert(1, 'Count', clean_df.groupby(by=['Group'])['Group'].count())
# Out:
#           Difference  Starting Median Salary  Mid-Career Median Salary  \
# Group
# STEM      101,600.00               53,862.50                 90,812.50
# Business  103,958.33               44,633.33                 75,083.33
# HASS       95,218.18               37,186.36                 62,968.18
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# STEM                              56,025.00                         157,625.00
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
